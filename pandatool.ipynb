# %%
import pandas as pd

# %%
df = pd.read_csv("G:/archive/Indian_Kids_Screen_Time.csv")

# %%
print(df.head())
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# ...

# %%
df.head()       # First 5 rows
df.tail()       # Last 5 rows
df.sample(5)    # Random 5 rows
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 4709   11    Male                      5.28     Smartphone
# 6379   16  Female                      4.31     Smartphone
# 1081   18    Male                      6.96             TV
# 5180   13  Female                      4.85     Smartphone
# 8159   10    Male                      3.91             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 4709                        True                               0.37
# 6379                        True                               0.38
# 1081                        True                               0.39
# 5180                        True                               0.46
# 8159                        True                               0.49
#
#               Health_Impacts Urban_or_Rural
# 4709              Poor Sleep          Urban
# 6379                     NaN          Urban
# 1081              Eye Strain          Rural
# ...

# %%
df.shape        # (rows, columns)
df.columns      # Column names
df.info()       # Data types & null values
df.describe()   # Summary statistics (mean, std, etc.)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# ...

# %%
df['Age']                  # Single column
df[['Age', 'Gender']]      # Multiple columns
df.iloc[0]                 # Row by index
df.loc[0, 'Age']           # Cell by label
# Out:
# np.int64(14)

# %%
df[df['Age'] > 13]
df[df['Gender'] == 'Female']
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# 5      14  Female                      4.88     Smartphone
# ...   ...     ...                       ...            ...
# 9700   14  Female                      5.30     Smartphone
# 9704    8  Female                      4.23             TV
# 9705    9  Female                      8.07             TV
# 9708   17  Female                      4.43     Smartphone
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 1                           True                               0.30
# 2                           True                               0.32
# ...

# %%
df.sort_values('Age')
df.sort_values('Age', ascending=False)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 3404   18  Female                      6.86     Smartphone
# 9665   18  Female                      5.94     Smartphone
# 10     18    Male                      3.53         Tablet
# 9      18    Male                      3.24         Tablet
# 3651   18  Female                      4.61     Smartphone
# ...   ...     ...                       ...            ...
# 9630    8    Male                      9.70         Tablet
# 9691    8  Female                      2.26             TV
# 2804    8  Female                      0.26         Tablet
# 2805    8  Female                      0.00     Smartphone
# 2813    8    Male                      3.24             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 3404                        True                               0.33
# 9665                        True                               0.38
# ...

# %%
df.isnull().sum()
df.dropna(inplace=True)
df.fillna("Unknown", inplace=True)

# %%
df['NewColumn'] = df['Age'] * 2

# %%
df.rename(columns={'Age': 'Student_Age'}, inplace=True)

# %%
df.drop('Age', axis=1, inplace=True)  # Drop column
df.drop(0, axis=0, inplace=True)      # Drop row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.drop('Age', axis=1, inplace=True)  # Drop column
#       2 df.drop(0, axis=0, inplace=True)      # Drop row
#
# File c:\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
# ...

# %%
df['Gender'].value_counts()

# %%
df.groupby('Gender')['Age'].mean()

# %%
pd.merge(df1, df2, on='ID', how='inner')  # left, right, outer, inner

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.resample('M').mean()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.resample('M').mean()

# %%
df.to_csv("output.csv", index=False)
